# %%
from importlib import reload
import logging
logging.basicConfig(format='%(asctime)s|%(name)s|%(levelname)s|%(message)s',level=logging.INFO)
# %matplotlib notebook

import vis; reload(vis);

# %%
import data; reload(data);
ppd_LE16 = data.load_ppd()
# Out:
# 2018-02-11 20:42:11,384|data|INFO|Loaded './data/ppd_data_LE16_2018-02-10.csv.gz': (17928, 16)

# %%
ppd_LE16.property_type.value_counts()
# Out:
# D    7504
# S    4635
# T    4361
# F    1351
# O      77
# Name: property_type, dtype: int64

# %%
ppd_LE16.transaction_category.value_counts()
# Out:
# A    17721
# B      207
# Name: transaction_category, dtype: int64

# %%
ppd_LE16.describe(include='all')
# Out:
#                                    unique_id    price_paid  \
# count                                  17928  1.792800e+04
# unique                                 17928           NaN
# top     31FB4C17-BFD1-57B9-E050-A8C063053436           NaN
# freq                                       1           NaN
# first                                    NaN           NaN
# last                                     NaN           NaN
# mean                                     NaN  1.882570e+05
# std                                      NaN  1.749774e+05
# min                                      NaN  4.000000e+03
# 25%                                      NaN  9.500000e+04
# 50%                                      NaN  1.550000e+05
# 75%                                      NaN  2.360000e+05
# max                                      NaN  1.000000e+07
#
#                   deed_date  postcode property_type new_build estate_type  \
# ...

# %%
reload(vis)
vis.plot_transactions(ppd_LE16)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ppd_LE16[(ppd_LE16.paon=='6')&(ppd_LE16.street.str.lower().str.startswith('woodbreach'))]
# Out:
#                                  unique_id  price_paid  deed_date  postcode  \
# 5481  0A6FAE52-2232-4F34-9CC5-61B5C085D409      167000 2003-12-19  LE16 7XG
# 5482  DF8CCE1E-F4C1-4F3B-BEA4-C06507C91056       92500 2000-08-25  LE16 7XG
#
#      property_type new_build estate_type saon paon            street  \
# 5481             D         N           F  NaN    6  WOODBREACH DRIVE
# 5482             D         Y           F  NaN    6  WOODBREACH DRIVE
#
#                locality               town    district          county  \
# 5481  MARKET HARBOROUGH  MARKET HARBOROUGH  HARBOROUGH  LEICESTERSHIRE
# 5482                NaN  MARKET HARBOROUGH  HARBOROUGH  LEICESTERSHIRE
#
#      transaction_category                                    linked_data_uri
# 5481                    A  http://landregistry.data.gov.uk/data/ppi/trans...
# 5482                    A  http://landregistry.data.gov.uk/data/ppi/trans...

# %%
ppd_woodbreach = ppd_LE16[ppd_LE16.street.fillna('-').str.lower().str.startswith('woodbreach')]
print(ppd_woodbreach.shape)
print(ppd_woodbreach['paon'].value_counts()[0:3])
# Out:
# (104, 16)
# 5     5
# 57    5
# 12    4
# Name: paon, dtype: int64

# %%
reload(vis);
vis.plot_transactions(ppd_woodbreach, by='paon', n_groups = 15)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 5
# (5, 16)
# 57
# (5, 16)
# 12
# (4, 16)
# 39
# (4, 16)
# 8
# (4, 16)
# 26
# (4, 16)
# 17
# (4, 16)
# 20
# (4, 16)
# 55
# (4, 16)
# 33
# (4, 16)
# 28
# (3, 16)
# 29
# (3, 16)
# 41
# (3, 16)
# 16
# (3, 16)
# 1
# (3, 16)

# %%
vis.pp.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
