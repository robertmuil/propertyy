# %%
from importlib import reload
import logging
logging.basicConfig(format='%(asctime)s|%(name)s|%(levelname)s|%(message)s',level=logging.INFO)

# %matplotlib notebook

# %%
import data; reload(data);
ppd_LE16 = data.load_ppd()
# Out:
# 2018-02-10 17:44:37,851|data|INFO|Loaded './data/ppd_data_LE16_2018-02-10.csv.gz': (17928, 16)

# %%
ppd_LE16.property_type.value_counts()
# Out:
# D    7504
# S    4635
# T    4361
# F    1351
# O      77
# Name: property_type, dtype: int64

# %%
ppd_LE16.transaction_category.value_counts()
# Out:
# A    17721
# B      207
# Name: transaction_category, dtype: int64

# %%
ppd_woodreach.describe(include='all')
# Out:
#                                    unique_id    price_paid  \
# count                                  17928  1.792800e+04
# unique                                 17928           NaN
# top     C2B343CB-6BD6-4830-8CE7-968CB7FBD624           NaN
# freq                                       1           NaN
# first                                    NaN           NaN
# last                                     NaN           NaN
# mean                                     NaN  1.882570e+05
# std                                      NaN  1.749774e+05
# min                                      NaN  4.000000e+03
# 25%                                      NaN  9.500000e+04
# 50%                                      NaN  1.550000e+05
# 75%                                      NaN  2.360000e+05
# max                                      NaN  1.000000e+07
#
#                   deed_date  postcode property_type new_build estate_type  \
# ...

# %%
ppd_LE16.describe(include='all')
# Out:
#                                    unique_id    price_paid  \
# count                                  17928  1.792800e+04
# unique                                 17928           NaN
# top     C2B343CB-6BD6-4830-8CE7-968CB7FBD624           NaN
# freq                                       1           NaN
# first                                    NaN           NaN
# last                                     NaN           NaN
# mean                                     NaN  1.882570e+05
# std                                      NaN  1.749774e+05
# min                                      NaN  4.000000e+03
# 25%                                      NaN  9.500000e+04
# 50%                                      NaN  1.550000e+05
# 75%                                      NaN  2.360000e+05
# max                                      NaN  1.000000e+07
#
#                   deed_date  postcode property_type new_build estate_type  \
# ...

# %%
ppd_woodreach.plot.line(y='price_paid',x='deed_date', marker='x')
# Out:
# <img src="data:image/png;base64,..." width="1002.5">
